# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/home/arraygen/Akshata/Machine_Learning/5_to_10_Machine_Learning/Linear_Regression_and_random_forest/insurance.csv")

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
def smoker(yes):
    if yes =="yes":
        return 1
    else:
        return 0
dataset["smoker"]=dataset["smoker"].apply(smoker)

def sex(s):
    if s =="male":
        return 1
    else:
        return 0
dataset["sex"]=dataset["sex"].apply(sex)

# %%
dataset.corr()["charges"]
# Out:
# age         0.299008
# sex         0.057292
# bmi         0.198341
# children    0.067998
# smoker      0.787251
# charges     1.000000
# Name: charges, dtype: float64

# %%
sns.heatmap(dataset.corr().abs())

# %%
plt.figure(figsize=(10,7))
ax = sns.heatmap(dataset.corr().abs(), annot = True, cmap="YlGnBu")

# %%
figure = ax.get_figure()   
figure.savefig("output.png")

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(x="smaker", y="charges")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-5cf697721360> in <module>()
#       2 # Show the results of a linear regression within each dataset
#       3 sns.lmplot(x="smaker", y="charges", col="bmi", hue="age", data=dataset,
# ----> 4            col_wrap=2, ci=None, palette="muted", height=4)
#
# /home/arraygen/.local/lib/python3.6/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     577     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     578     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 579     data = data[cols]
#     580
#     581     # Initialize the grid
#
# /home/arraygen/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /home/arraygen/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /home/arraygen/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['smaker'] not in index"
